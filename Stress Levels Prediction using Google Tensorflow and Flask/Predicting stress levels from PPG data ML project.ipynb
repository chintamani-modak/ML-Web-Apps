# %% [markdown]
# # **Harnessing Heartbeats: Leveraging TensorFlow and Flask to Predict Stress Levels from PPG Data**

# %% [markdown]
# ![pic](pic.png)

# %% [markdown]
# # **Unlocking Stress Insights with the Power of Photoplethysmography and AI**
#
# - In our latest project, we dive into the fascinating world of Photoplethysmography (PPG) to predict stress levels. PPG is a non-invasive method that uses infrared light to monitor the volumetric changes in blood circulation, providing a window into the workings of the cardiovascular system.
#
# - One of the critical metrics we focus on is Heart Rate Variability (HRV). HRV measures the time variations between consecutive heartbeats and is widely recognized for its ability to indicate stress, general health, and potential disease states. By pinpointing the peaks in a PPG signal, we can accurately determine the timing of heartbeats, which is crucial for calculating these intervals.
#
# - For this project, we've sourced our dataset from Kaggle and have embarked on the task of classifying stress levels using a Feed-Forward Artificial Neural Network (FF-ANN) developed in TensorFlow. This approach allows us to harness the power of machine learning to not only model but also predict stress levels effectively.
#
# - After training, our model undergoes rigorous testing to ensure accuracy and reliability. The final step involves deploying this model into a practical application—a web app built using the Flask framework. This app will enable users to input new test data and receive instant stress level predictions, making our research applicable and accessible in everyday life.

# %% [markdown]
# # Introduction: Revolutionizing Stress level prediction with Google TensorFlow & Flask

# %% [markdown]
# **Introduction**:
#
# Welcome to a riveting exploration of Photoplethysmography (PPG), spotlighted on Medium under 'Google TensorFlow AI/ML Applications'. As a Data scientist & AI Consultant, I invite you to journey through the dynamic landscape of machine learning. We'll leverage the formidable capabilities of Google's TensorFlow and the streamlined efficacy of the Flask micro web framework, developed by Armin Ronacher, to innovate web application deployment and creation.
#
# **The Challenge**:
#
# The quest to predict stress levels using PPG data presents multifaceted challenges. Our TensorFlow-powered neural network aims to maintain impeccable signal quality for precise HRV feature extraction, select robust features applicable across diverse individuals, and adeptly manage time-series data. Compounding this, we face hurdles in overcoming class imbalances, ensuring model generalization, integrating real-time predictions into a Flask web app, and upholding stringent ethical and privacy standards to foster trust and compliance.
#
# **Introducing TensorFlow & Flask**:
#
# Dive into the depths of TensorFlow, a brainchild of Google Brain, epitomizing advancement in machine learning. This tool transcends its utilitarian purposes by democratizing complex analytics and spearheading predictive innovations. Accompanying TensorFlow is Flask, a Python-based lightweight web framework renowned for its simplicity and adaptability, offering a scalable foundation for web development since its inception in 2010.
#
# **Join the Journey**:
#
# This venture is more than a technological exploration—it’s a voyage into the heart of data-driven discovery, where sophisticated algorithms meet empirical inquiry. I encourage you to join me in navigating the intricacies of stress prediction and unlocking the profound potential of TensorFlow and Flask. Together, we'll demystify cutting-edge technologies and harness them to illuminate the subtle nuances of human stress levels.

# %% [markdown]
# # Project Approach

# %% [markdown]
# ![Screenshot 2024-02-01 204110](Screenshot%202024-02-01%20204110.png)

# %% [markdown]
# **Project Overview**:
#
# Embark on an innovative journey with us as we tackle a machine learning project aimed at predicting stress levels using state-of-the-art techniques. Our project encompasses several critical stages: project scoping, data collection and preprocessing, modeling, and ultimately, the deployment of a Flask-powered web application.
#
# **Scoping Phase**:
#
# The initial phase of our project lays the foundation for success. We will clearly define our objectives, pinpoint the key variables that predict stress, and identify the most reliable data sources while considering potential constraints. This meticulous planning ensures a targeted approach, setting the stage for impactful results.
#
# **Data Collection and Preprocessing**:
#
# Data is at the heart of every machine learning endeavor. In this phase, we delve into the rich dataset available, focusing on a variety of features such as mean, median, error, RMSD, and percentile values. Each feature will be meticulously scaled using a standard scaler to normalize the data, enhancing the predictive power of our models.
#
# **Modeling**:
#
# The core of our project involves the strategic application of Feedforward Neural Networks. This sophisticated modeling technique will be employed to train robust classification models, designed to accurately predict stress levels from complex datasets.
#
# **Expansion into Web Application**:
#
# Elevating our project, we will extend beyond traditional modeling to include the creation and deployment of a machine learning web application using the Flask framework. This phase not only showcases our model's practical application but also enhances accessibility, allowing users to interact with our predictions in real-time.

# %% [markdown]
# # Methodology Unveiled: Stress level Forecasting with Google TensorFlow & Flask framework

# %% [markdown]
# **Unleashing the Power of TensorFlow**:
#
# Developed by the visionary minds at Google Brain, TensorFlow stands as a pinnacle of innovation in the machine learning landscape. As an open-source library, it not only excels in complex numerical computations—making it a powerhouse for deep learning challenges—but also offers unmatched flexibility for a wide array of data-driven tasks. This accessibility empowers developers and researchers globally to push the boundaries of what's possible in both commercial and academic pursuits.
#
# **Leveraging Flask for Web Application Development**:
#
# For the deployment of our web application, we've chosen Flask, a Python-based framework known for its lightweight structure and high adaptability. Since its debut in 2010, Flask has provided a robust yet simple foundation for web development, enabling developers to create scalable and efficient web applications with ease. Its minimalist design and powerful capabilities make it the ideal choice for developers looking to bring sophisticated projects to life swiftly.

# %% [markdown]
# # Process: Charting the Course

# %% [markdown]
# Our Enlightening Journey Through Jupyter Notebook:
#
# - **Defining the Project**: Our quest begins by delving into the core business problem, setting a clear direction for our analytical efforts.
# - **Data Collection & Understanding**: We embark on the meticulous task of gathering data, unraveling its complexities to uncover hidden insights that lie beneath the surface.
# - **Data Preprocessing**: At the heart of our analysis lies the critical process of cleansing and structuring data, preparing it for advanced machine learning interpretation.
# - **Feature Engineering & Selection**: Here, we identify the key attributes that will fuel our predictive accuracy, selecting only the most impactful features.
# - **Model Selection**: With Auto-Sklearn at the helm, we navigate through a sea of algorithms, pinpointing the one that stands out as our champion in performance.
# - **Evaluation**: Our journey doesn’t end with model development; we rigorously test our Feedforward Neural Network, scrutinizing its accuracy, precision, recall, and more to ensure it meets our stringent standards.
# - **Web App Creation**: The final frontier of our adventure involves translating the model's predictions into a dynamic web application, providing a window for the world to view the compelling visualizations of our findings.

# %% [markdown]
# ## Step 1: Import Libraries and Read Dataset

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import tensorflow.keras as k
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import time
# Out:
# 2024-04-29 22:01:57.122794: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Step 2: Data Preparation

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR  ...    higuci  datasetId  condition
# 0  885.157845  853.763730  140.972741  ...  1.163485          2          0
# 1  939.425371  948.357865   81.317742  ...  1.084711          2          1
# 2  898.186047  907.006860   84.497236  ...  1.176315          2          1
# 3  881.757864  893.460030   90.370537  ...  1.179688          2          0
# 4  809.625331  811.184865   62.766242  ...  1.249612          2          0
#
# [5 rows x 36 columns]

# %%
label = ['condition']
features = ['MEAN_RR','RMSSD','pNN25','pNN50','LF','HF','LF_HF']

# %%
# Scaling of the features
scaler = StandardScaler()
scaler.fit(df[features])
df[features] = scaler.transform(df[features])

# %%
X = df[features].values
y = df[label].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=40 )

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (258502, 7) (258502, 1) (110787, 7) (110787, 1)

# %% [markdown]
# Use Keras dot utils dot 2 categorical function. Since the output is a class and there are 3 classes 0,1,2 we will have to change the type of output from int to categorical.

# %%
y_train = k.utils.to_categorical(y_train)
y_test = k.utils.to_categorical(y_test)

# %% [markdown]
# ## Step 3: Model Creation

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
# Model Building

model = Sequential()
model.add(Dense(50, activation='relu', kernel_initializer= 'he_normal',input_shape=(X_train.shape[1],) ))
model.add(Dense(20, activation='relu', kernel_initializer= 'he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer= 'he_normal'))
model.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=1024, verbose=1)
# Out:
# Epoch 1/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5968 - loss: 0.8985 - val_accuracy: 0.6830 - val_loss: 0.7132
# Epoch 2/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6997 - loss: 0.6728 - val_accuracy: 0.7585 - val_loss: 0.5653
# Epoch 3/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7687 - loss: 0.5354 - val_accuracy: 0.8081 - val_loss: 0.4770
# Epoch 4/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8220 - loss: 0.4555 - val_accuracy: 0.8322 - val_loss: 0.4213
# Epoch 5/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8430 - loss: 0.4053 - val_accuracy: 0.8572 - val_loss: 0.3732
# Epoch 6/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8612 - loss: 0.3607 - val_accuracy: 0.8713 - val_loss: 0.3405
# Epoch 7/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8767 - loss: 0.3270 - val_accuracy: 0.8841 - val_loss: 0.3115
# Epoch 8/50
# ...

# %%
# Plot Accuracy, Loss curves

pd.DataFrame(history.history).plot(figsize=(10,7))
# Out:
# <Axes: >

# %% [markdown]
# From the above we can observe that there is no overfitting involved in our model since thetre is a steady decrease in the validation loss and training loss.

# %% [markdown]
# ## Step 4: Model testing on Test data

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test[features] = scaler.transform(df_test[features])
df_test[features].head()
# Out:
#     MEAN_RR     RMSSD     pNN25     pNN50        LF        HF     LF_HF
# 0 -1.001159 -0.634891 -0.598837 -0.874583 -0.575814  0.602911 -0.295775
# 1 -0.024971  1.048686  1.361573 -0.672601  1.080403 -0.280746 -0.157544
# 2  0.897836  1.544671  1.743894  0.943254  1.965161 -0.511482  0.037412
# 3 -0.175046 -0.777935 -0.623241 -0.335965 -0.767443 -0.477196 -0.241658
# 4 -0.721825 -0.393071 -0.476820 -0.201310 -0.735541 -0.089133 -0.280126

# %%
X = df_test[features].values
y = df_test[label].values

# %%
y = k.utils.to_categorical(y)

# %%
loss,acc = model.evaluate(X,y,verbose=1)
# Out:
# 1283/1283 ━━━━━━━━━━━━━━━━━━━━ 1s 576us/step - accuracy: 0.9643 - loss: 0.1063

# %% [markdown]
# ## Step 5: Build prediction pipeline

# %%
data = pd.read_csv('test.csv')

# %% [markdown]
# Now we will read one row or one sample from the dataset and then transform it using the same scaler object, and then reshape it for input into our model.

# %%
t = scaler.transform(data[features].iloc[5550].values.reshape(1,-1))
print(t)
# Out:
# [[ 0.68125653 -0.5883666  -0.7045857  -0.73992842 -0.70816139 -0.72346888
#   -0.0876444 ]]

# %%
y_pred = model.predict(t)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
print(np.argmax(y_pred[0]))
print(data[label].iloc[5550])
# Out:
# 0
# condition    0
# Name: 5550, dtype: int64

# %% [markdown]
# ## Step 6: Saving of the model

# %% [markdown]
# Now we will save the model we are importing Joblib to save our scalar model or a scalar object using Joblib dot dump.

# %%
import joblib
joblib.dump(scaler, 'scaler.joblib', compress=9)
model.save('tfmodel.h5')

# %%
print(df[features].iloc[1])
print(df[label].iloc[1])
# Out:
# MEAN_RR    0.744562
# RMSSD     -0.488516
# pNN25     -0.517493
# pNN50     -0.874583
# LF        -0.446586
# HF        -0.818019
# LF_HF      0.585608
# Name: 1, dtype: float64
# condition    1
# Name: 1, dtype: int64

# %% [markdown]
# ## Step 7: Conclusion

# %% [markdown]
# - In this project, we've mastered the use of Feedforward Neural Networks to predict stress levels from PPG data, culminating in the creation and local deployment of a Flask web application. This practical application demonstrates the integration of advanced machine learning techniques with modern web technology to solve complex health-related challenges.
# - We sourced our data from Kaggle, leveraging a rich dataset to classify stress levels using a Feed-Forward Artificial Neural Network (FF-ANN) crafted in TensorFlow. This strategic approach enabled us to exploit the full capabilities of machine learning, not just to model but to predict stress with remarkable accuracy.
# - Traditional statistical methods, while robust, often demand extensive theoretical knowledge and lengthy implementation. The advent of neural networks has revolutionized this landscape.
# - By adopting neural networks, we significantly cut down on both time and effort, bypassing the intricate theoretical groundwork required for traditional statistics.
# Neural networks provide unparalleled flexibility, allowing us to experiment with various configurations and iterate rapidly. This adaptability has empowered us to fine-tune our models and achieve an optimal performance level, pushing the boundaries of what we can achieve with our data.
